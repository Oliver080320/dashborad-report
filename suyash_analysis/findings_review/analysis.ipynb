# %% [markdown]
# # Sales dashboard dataset audit
# Read-only calculations. Run from the findings_review directory. Source files are never written. See analyze.py and the source inventory for rules and hashes.

# %%
# %run analyze.py

# %%
import pandas as pd
pd.read_csv("evidence/issues_register.csv")
